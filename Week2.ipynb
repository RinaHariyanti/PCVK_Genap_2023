# %% [markdown]
# <a href="https://colab.research.google.com/github/RinaHariyanti/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kucing.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
#vertikal
#img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
#Horizontal
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),1)

# simpan File image
# cv.imwrite('/content/drive/MyDrive/PCVK/Images/kucing.jpg', img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(5,5))     #ubah-ubah ukuran (10,10)dengan (5,5)
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
# cv.rectangle(black_img,pt1=(lebar,tinggi),pt2=(lebar,tinggi),color=(R,G,B),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,20,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
# cv.circle(black_img,center=(lebar,tinggi),radius=jari-jari,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
# cv.line(black_img,pt1(Start)=(lebar,panjang),pt2(End)=(lebar,panjang),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,300),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
# cv.putText(black_img,text='Hello',org=(lebar,tinggi),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
# vertices = titik
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 chanel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ## Tugas

# %% [markdown]
# cmap itu berpengaruh.
# ### Yang berpengaruh itu read nya. show tidak berpengaruh
# ### read cv, show cv --> RGB
# ### read matplotlib, show matplotlib --> RGB
# ### read cv, show matplotlib --> BGR
# ### read matplotlib, show cv --> BGR
#
# PR
# menggambar diagonal dengan squer dengan manual

# %%
# Menyamakan Presepsi
# read opencv, show matplotlib ==> tidak sesuai dg mata yg kita lihat
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpeg')
plt.imshow(img)

# %%
# read matplotlib, show opencv ==> tidak sesuai dg mata yg kita lihat
img = plt.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpeg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7F5357429580>

# %%
# read matplotlib, show matplotlib ==> sesuai dg mata yg kita lihat
img = plt.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpeg')
plt.imshow(img)

# %%
# read opencv, show opencv ==> sesuai dg mata yg kita lihat
img7 = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpeg')
cv2_imshow(img7)
# Out:
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7F53574426D0>

# %%
# read opencv, kemudian dikonversi ke RGB, dan show menggunakan matplotlib ==> gambar sesuai dg mata kita
img4 =cv.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpeg')
img4 = cv.cvtColor(img,cv.COLOR_RGB2BGR) # ini namanya konversi
plt.imshow(img4)

# %%
# read opencv, kemudian dikonversi ke RGB, dan show menggunakan opencv ==> gambar sesuai dg mata kita
img4 =cv.imread('/content/drive/MyDrive/PCVK/Images/kitten.jpeg')
img4 = cv.cvtColor(img,cv.COLOR_RGB2BGR) # ini namanya konversi
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7F5357429880>

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
R,G,B = cv.split(img3)
# Membuat method zeros untuk membuat array kosong
zeros = np.zeros(img3.shape[:2], dtype="uint8")
# Tampilkan warna Merah
red = cv.merge([R,zeros,zeros])
plt.imshow(red)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
R,G,B = cv.split(img3)
# Membuat method zeros untuk membuat array kosong
zeros = np.zeros(img3.shape[:2], dtype="uint8")
# Tampilkan warna hijau
green = cv.merge([zeros,G,zeros])
plt.imshow(green)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
R,G,B = cv.split(img3)
# Membuat method zeros untuk membuat array kosong
zeros = np.zeros(img3.shape[:2], dtype="uint8")
# Tampilkan warna Biru
blue = cv.merge([zeros,zeros,B])
plt.imshow(blue)

# %%
#2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# Ambil gambar dari google drive
img = cv.imread('/content/drive/MyDrive/PCVK/Images/foto.jpg')
# Mengonversi gambar dari BGR ke RGB
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# Membuat variable RGB untuk dilakukan split warna pada gambar
R,G,B = cv.split(img2)
# Membuat method zeros untuk membuat array kosong
zeros = np.zeros(img2.shape[:2], dtype="uint8")
# Tampilkan warna merah hijau
red_blue = cv.merge([R,zeros,B])
plt.imshow(red_blue)

# %%
green_blue = cv.merge([zeros,G,B])
plt.imshow(green_blue)

# %%
#3. Tampilkan image baris ke 20-115, kolom 25-120!
img_foto = cv.imread('/content/drive/MyDrive/PCVK/Images/foto.jpg')
img_foto1 = cv.cvtColor(img3, cv.COLOR_BGR2RGB)
crop = img_foto1[20:115, 25:120]
plt.imshow(crop)

# %%
#4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
red = cv.merge([R,zeros,zeros])
y=5
x=0
h=30
w=red.shape[1]
crop = red[y:h, x:w]
plt.imshow(crop)

# %%
black_img3 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img3)

# %%
cv.rectangle(black_img3, pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(black_img3, pt1=(200,15),pt2=(250,250),color=(255,0,0),thickness=5)
cv.rectangle(black_img3, pt1=(0,240),pt2=(210,120),color=(0,0,255),thickness=10)
cv.rectangle(black_img3, pt1=(150,20),pt2=(310,130),color=(255,0,255),thickness=5)
cv.rectangle(black_img3, pt1=(20,50),pt2=(350,100),color=(255,255,0),thickness=5)
plt.imshow(black_img3)

# %%
# Menampilkan gambar dengan posisi terbalik
img3 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(5,5))     #ubah-ubah ukuran (5,5)
ax = fig.add_subplot(111)
ax.imshow(img3)

# %%
#7 Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto)
img4 = cv.imread('/content/drive/MyDrive/PCVK/Images/foto.jpg')
img5 = cv.cvtColor(img4, cv.COLOR_BGR2RGB)
cv.circle(img5, (1250,1250), 700, (255,255,0), 50)
cv.rectangle(img5, (1800,550), (750,1900), (0,255,255), 50)
plt.imshow(img5)

# %%
#8 Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers! 
img6 = cv.imread('/content/drive/MyDrive/PCVK/Images/foto.jpg')
plt.imshow(img6)
#Menjadikan warna RGB
img7 = cv.cvtColor(img6,cv.COLOR_BGR2RGB)
plt.imshow(img7)
# Membuat rectangle pada bagian sudut kiri bawah
cv.rectangle(img7,pt1=(500,3700),pt2=(50,3900),color=(0,255,0),thickness=60)
plt.imshow(img7)

# %%
#9 Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda
font = cv.FONT_HERSHEY_COMPLEX
cv.putText(img7,text='Nisa',org=(1000,3000),fontFace=font,fontScale=4,color=(255,255,0),thickness=10,lineType=cv.LINE_AA)
plt.imshow(img7)
